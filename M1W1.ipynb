# %%
#this is a test commit

import pandas as pd
import numpy as np

print ("test commit")

3+3
# Out:
# test commit
# 6

# %%
#test commit

x = 5

z = 7

x+z
# Out:
# 12

# %%
print ('test commit 2')
# Out:
# test commit 2
